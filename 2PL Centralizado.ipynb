# %% [markdown]
# ## Bloqueo 2Pl Centralizado usando Threads
#
# ```{java}
# import java.util.Random;
# import java.util.concurrent.locks.Lock;
# import java.util.concurrent.locks.ReentrantLock;
#
#
#
# //Operacion tiene argumentos definidos
# class Operacion{
#    public int num;
#    public String tipo,arg,value,result;
#
#  public Operacion(int num, String tipo, String arg, String value, String result){
#      this.num = num;
#      this.tipo = tipo;
#      this.arg = arg;
#      this.value = value;
#      this.result = result;
#
#  }
#
# }
#
#
# //Se crean las transacciones y la operacion
# //Se crea el hilo
# //Se corre el hilo
# public class Ejemplo{
#
#
#   public static void main(String[] args){
#     Ejemplo instance1 = new Ejemplo();
#
#     Operacion Op1 = new Operacion(1,"Leer","","","");
#     Operacion Op2 = new Operacion(1,"Escribir","","","");
#     Operacion Op3 = new Operacion(1,"Commit","","","");
#     Operacion Op4 = new Operacion(1,"Abort","","","");
#
#
#
#     Thread t1 = new Thread(new Transaccion(Op1), "Operacion-1");
#     Thread t2 = new Thread(new Transaccion(Op2), "Operacion-2");
#
#
#     long  startTime = System.currentTimeMillis();
#     t1.start();
#     t2.start();
#
#   }
# }
#
#
#
# //Transacciones ejecutan sus operaciones
# //Cuantas veces se corren los hilos
# class Transaccion implements Runnable{
#   private  Operacion Op;
#
#   private final Lock lock = new ReentrantLock();
#
#   public Transaccion(Operacion P){
#       this.Op = P;
#   }
#
#   public void run() {
#     Random random = new Random();
#     // Loop 10
#     for (int counter = 0; counter <= 10; counter++) {
#       try {
#         Thread.sleep(random.nextInt(5));
#       } catch (InterruptedException e) {
#         System.out.println(Thread.currentThread().getName());
#     }
#       this.aplicar();
#       }
#     }
#
#
#
#
# //Algoritmo 2PL
#   public boolean isBloqueado(){
#
#     Boolean mainLock = false;
#     Boolean OtroLock = false;
#
#     if(this.Op.tipo == "Leer" || this.Op.tipo =="Escribir"){
#         try{
#               mainLock = lock.tryLock();
#             //  OtroLock = P.lock.tryLock();
#
#         }
#         finally{
#           if(!mainLock){
#           lock.unlock();
#           }
#         //  OtroLock.lock.unlock();
#         }
#
#     }
#     else{
#       lock.unlock();
#       return false;
#     }
#     return mainLock;
#
#
#   }
#
#
# //Pregunta a run si puede obtener el candado, si no lo puedes obtener se espera y si lo obtiene lo usa y lo libera
#   public void aplicar() {
#     // Check if Lock is already exist?
#     if (isBloqueado()) {
#       try {
#         System.out.println(Thread.currentThread().getName()+ " Comienza la operacion");
#         System.out.println(Thread.currentThread().getName() + " Bloqueo Aplicado");
#       } finally {
#         lock.unlock();
#         System.out.print(Thread.currentThread().getName()+"  Bloqueo Liberado");
#       }
#     } else {
#       System.out.print("Bloqueo Activado en espera de Liberacion");
#     }
#   }
#
#
# }
#
# ```

# %% [markdown]
# <p>Operacion-1 Comienza la operacion de ----&gt;:Leer<br />
# Operacion-1 Bloqueo Aplicado<br />
# Operacion-1 Bloqueo Liberado<br />
# Operacion-1 Comienza la operacion de ----&gt;:Leer<br />
# Operacion-2 Comienza la operacion de ----&gt;:Escribir<br />
# Operacion-2 Bloqueo Aplicado<br />
# Operacion-1 Bloqueo Aplicado<br />
# Operacion-2 Bloqueo Liberado<br />
# Operacion-1 Bloqueo Liberado<br />
# Operacion-1 Comienza la operacion de ----&gt;:Leer<br />
# Operacion-1 Bloqueo Aplicado<br />
# Operacion-1 Bloqueo Liberado<br />
# Operacion-2 Comienza la operacion de ----&gt;:Escribir<br />
# Operacion-2 Bloqueo Aplicado<br />
# Operacion-2 Bloqueo Liberado<br />
# Operacion-1 Comienza la operacion de ----&gt;:Leer<br />
# Operacion-1 Bloqueo Aplicado<br />
# Operacion-1 Bloqueo Liberado<br />
# Operacion-2 Comienza la operacion de ----&gt;:Escribir<br />
# Operacion-2 Bloqueo Aplicado<br />
# Operacion-2 Bloqueo Liberado<br />
# Operacion-1 Comienza la operacion de ----&gt;:Leer<br />
# Operacion-1 Bloqueo Aplicado<br />
# Operacion-1 Bloqueo Liberado<br />
# Operacion-1 Comienza la operacion de ----&gt;:Leer<br />
# Operacion-1 Bloqueo Aplicado<br />
# Operacion-1 Bloqueo Liberado<br />
# Operacion-1 Comienza la operacion de ----&gt;:Leer<br />
# Operacion-1 Bloqueo Aplicado<br />
# Operacion-1 Bloqueo Liberado<br />
# Operacion-2 Comienza la operacion de ----&gt;:Escribir<br />
# Operacion-2 Bloqueo Aplicado<br />
# Operacion-2 Bloqueo Liberado<br />
# Operacion-2 Comienza la operacion de ----&gt;:Escribir<br />
# Operacion-2 Bloqueo Aplicado<br />
# Operacion-2 Bloqueo Liberado<br />
# Operacion-1 Comienza la operacion de ----&gt;:Leer<br />
# Operacion-1 Bloqueo Aplicado<br />
# Operacion-1 Bloqueo Liberado<br />
# Operacion-1 Comienza la operacion de ----&gt;:Leer<br />
# Operacion-1 Bloqueo Aplicado<br />
# Operacion-1 Bloqueo Liberado<br />
# Operacion-2 Comienza la operacion de ----&gt;:Escribir<br />
# Operacion-2 Bloqueo Aplicado<br />
# Operacion-2 Bloqueo Liberado<br />
# Operacion-2 Comienza la operacion de ----&gt;:Escribir<br />
# Operacion-2 Bloqueo Aplicado<br />
# Operacion-1 Comienza la operacion de ----&gt;:Leer<br />
# Operacion-1 Bloqueo Aplicado<br />
# Operacion-2 Bloqueo Liberado<br />
# Operacion-1 Bloqueo Liberado<br />
# Operacion-1 Comienza la operacion de ----&gt;:Leer<br />
# Operacion-2 Comienza la operacion de ----&gt;:Escribir<br />
# Operacion-2 Bloqueo Aplicado<br />
# Operacion-1 Bloqueo Aplicado<br />
# Operacion-2 Bloqueo Liberado<br />
# Operacion-1 Bloqueo Liberado<br />
# Operacion-2 Comienza la operacion de ----&gt;:Escribir<br />
# Operacion-2 Bloqueo Aplicado<br />
# Operacion-2 Bloqueo Liberado<br />
# Operacion-2 Comienza la operacion de ----&gt;:Escribir<br />
# Operacion-2 Bloqueo Aplicado<br />
# Operacion-2 Bloqueo Liberado<br />
# Operacion-2 Comienza la operacion de ----&gt;:Escribir<br />
# Operacion-2 Bloqueo Aplicado<br />
# Operacion-2 Bloqueo Liberado</p>

# %% [markdown]
# ## Version Python
#
# def c2pl(transaccion,operacion):
#     lu = False
#     ColaLu = Queue()
#
#     lockMode = "Compatible"
#     if operacion.type == "Leer" or operacion.type == "Escribir":
#
#
#         if lu or lock == "Compatible":
#             lu = True
#             print "Comienza Transmision"
#             operacion.setID() #operacion en ejecucion
#             print "Seguro aplicado"
#
#         else:
#             ColaLu.enqueue(operacion) #si lu=True se encola
#
#     elif operacion.type == "Commit" or operacion.type == "Abort":
#
#         foreach operacion in transaccion: #vaciat cola (operaciones)
#             lu = False
#             if not ColaLu.isEmpty(): #cola vacia
#                 siguienteOperacion = ColaOperaciones.dequeue()
#                 print "Seguro aplicado enviado a Manejador de Operaciones"
#
#
#         print "Enviar Liberacion al coordinador"
